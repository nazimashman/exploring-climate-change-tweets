# %%
import tweepy
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import cnfg
from tqdm import tqdm
from pymongo import MongoClient
import json
import pandas as pd
import numpy as np
import nltk
from pprint import pprint
from gensim.parsing.preprocessing import remove_stopwords
from sklearn.feature_extraction.text import CountVectorizer
from gensim import corpora, models, similarities, matutils

import logging
from textblob import TextBlob
import gensim
import pyLDAvis
from pyLDAvis import gensim as gensimvis
import spacy

# %% [markdown]
# # Get updated document from database and create a dataframe

# %%
# Connect to monogodb server.  Make sure it's running first!
client = MongoClient('localhost', 27017)

client.list_database_names()
# Out:
# ['admin',
#  'climate_db',
#  'climate_db2',
#  'climate_db3',
#  'config',
#  'local',
#  'wildlife_db']

# %%
# Connect to the database for the first time
climate_db = client['climate_db2']

# Create a collection
climate_collection = climate_db.tweets

# %%
res = climate_db['tweets'].find()
res_list = [item for item in res]
df = pd.DataFrame(res_list)
df.head()
# Out:
#                         _id          created_at  favorite_count  \
# 0  5be9d6bab28573cc45ea668a 2018-11-12 19:13:43               0
# 1  5be9d6bab28573cc45ea668b 2018-11-12 19:13:42               0
# 2  5be9d6bab28573cc45ea668c 2018-11-12 19:13:41               0
# 3  5be9d6bab28573cc45ea668d 2018-11-12 19:13:34               0
# 4  5be9d6bab28573cc45ea668e 2018-11-12 19:13:32               0
#
#    retweet_count      screen_name  \
# 0              0     ndsandberg23
# 1              0  FresnoCountyGOP
# 2              0        PatDeRocH
# 3              0    Grace75646541
# 4              0  Totalrecoverys1
#
#                                                 text
# 0  Climate Change: hold my beer! https://t.co/ZBx...
# 1  Gov Brown said that Climate Change, not forest...
# 2  .@ExportDevCanada provided $10.4 billion in fi...
# 3  In 16 years from now humans will be underwater...
# 4  Climate Change Is Fueling California's Wildfir...

# %%
df.shape
# Out:
# (16633, 6)

# %%
train_text = df.text[:10000].values

# %% [markdown]
# # Look at some tweets

# %%
for i in train_text[:10]:
    print(i.lower())
# Out:
# climate change: hold my beer! https://t.co/zbx6o5ejts
# gov brown said that climate change, not forestry mgmt, is the cause of the fires. it seems more likely that forestr… https://t.co/mtgdnkq77x
# .@exportdevcanada provided $10.4 billion in financing to oil &amp; gas companies last year. today, @envirodefence joins… https://t.co/jhbulrvaic
# in 16 years from now humans will be underwater due to global warming and we will be so happy. what a exciting time… https://t.co/smnjxpovpc
# climate change is fueling california's wildfires, scientists say | here &amp; now https://t.co/fbzreqqbdc #smartnews
# debate moderators in this last election pushed candidates hard on #climatechange, especially in gubernatorial debat… https://t.co/zufw20yurd
# what happens when renewable energy economically outperforms fossil fuels like coal? are there any arguments for coa… https://t.co/mczp7gun5e
# the intensity of california’s forest fires can be directly related to global warming. the emotional sadness that wi… https://t.co/2dxyxsdgoy
# ron paul uses fossil fuels!
# at the 22nd of november: my phd defence @unileiden @fggaleiden on the coordination of eu sustainable development po… https://t.co/fkjz5ja9mm

# %% [markdown]
# # Text Preprocessing

# %%
stopwords = nltk.corpus.stopwords.words('english')
newStopWords = ['https', 'climate', 'change', 'co', 'climatechange', 'thing', 'via', 'de', 'global warming', 'global', 'rt', \
               'warming', 'th', 'amp', 'environment']
stopwords.extend(newStopWords)

# %%
# Create a CountVectorizer for parsing/counting words
count_vectorizer = CountVectorizer(ngram_range=(1, 3),  
                                   stop_words=stopwords, token_pattern="\\b[a-z][a-z]+\\b")
count_vectorizer.fit(train_text)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 3), preprocessor=None,
#         stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs',...nge', 'thing', 'via', 'de', 'global warming', 'global', 'rt', 'warming', 'th', 'amp', 'environment'],
#         strip_accents=None, token_pattern='\\b[a-z][a-z]+\\b',
#         tokenizer=None, vocabulary=None)

# %%
# Create the term-document matrix
# Transpose it so the terms are the rows
counts = count_vectorizer.transform(train_text).transpose()

# %%
# Convert sparse matrix of counts to a gensim corpus
corpus = matutils.Sparse2Corpus(counts)

# %%
id2word = dict((v, k) for k, v in count_vectorizer.vocabulary_.items())

# %%
len(id2word)
# Out:
# 111171

# %% [markdown]
# # Perform LDA

# %%
# Create lda model (equivalent to "fit" in sklearn)
lda = models.ldamulticore.LdaMulticore(corpus=corpus, num_topics=15, minimum_probability=0.05, id2word=id2word, passes=10)

# %%
pprint(lda.print_topics())
# Out:
# [(0,
#   '0.003*"help" + 0.003*"stop" + 0.002*"flooding" + 0.002*"deserts" + '
#   '0.002*"would" + 0.002*"flooding deserts" + 0.002*"deserts help" + '
#   '0.002*"help stop" + 0.002*"deserts help stop" + 0.002*"flooding deserts '
#   'help"'),
#  (1,
#   '0.002*"california" + 0.002*"trump" + 0.002*"fires" + 0.001*"need" + '
#   '0.001*"get" + 0.001*"fire" + 0.001*"today" + 0.001*"us" + 0.001*"sea" + '
#   '0.001*"level"'),
#  (2,
#   '0.003*"big" + 0.003*"new" + 0.003*"big oil" + 0.003*"oil" + 0.003*"even" + '
#   '0.003*"part" + 0.003*"study" + 0.003*"claims" + 0.003*"big oil claims" + '
#   '0.003*"oil claims"'),
#  (3,
#   '0.004*"wildfires" + 0.004*"california" + 0.002*"california wildfires" + '
#   '0.002*"us" + 0.002*"even" + 0.002*"scientists" + 0.002*"brown" + '
#   '0.001*"politics" + 0.001*"trump" + 0.001*"new"'),
#  (4,
#   '0.007*"energy" + 0.007*"government" + 0.006*"department" + '
#   '0.006*"protesters" + 0.006*"energy department" + 0.006*"blockade" + '
#   '0.005*"protesters blockade" + 0.005*"government energy" + 0.005*"blockade '
#   'government" + 0.005*"government energy department"'),
#  (5,
#   '0.007*"trump" + 0.006*"neil" + 0.006*"young" + 0.006*"home" + 0.006*"neil '
#   'young" + 0.006*"loses" + 0.006*"neil young loses" + 0.006*"young loses" + '
#   '0.006*"loses home" + 0.006*"young loses home"'),
#  (6,
#   '0.011*"wildfires" + 0.009*"brown" + 0.008*"california" + 0.008*"jerry" + '
#   '0.008*"jerry brown" + 0.008*"blames" + 0.007*"brown blames" + 0.006*"jerry '
#   'brown blames" + 0.006*"california wildfires" + 0.004*"blames california"'),
#  (7,
#   '0.013*"neil" + 0.012*"young" + 0.012*"neil young" + 0.012*"trump" + '
#   '0.011*"california" + 0.011*"home" + 0.010*"fires" + 0.010*"losing" + '
#   '0.010*"california fires" + 0.010*"criticises"'),
#  (8,
#   '0.002*"real" + 0.002*"new" + 0.001*"bears" + 0.001*"could" + '
#   '0.001*"california" + 0.001*"polar" + 0.001*"temperature" + 0.001*"carbon" + '
#   '0.001*"many" + 0.001*"energy"'),
#  (9,
#   '0.006*"california" + 0.005*"trump" + 0.004*"blames" + 0.004*"fires" + '
#   '0.003*"leads" + 0.003*"arrests" + 0.003*"protests leads" + 0.003*"protests" '
#   '+ 0.003*"leads arrests" + 0.003*"protests leads arrests"'),
#  (10,
#   '0.003*"california" + 0.003*"republican" + 0.002*"democrat" + 0.002*"ran" + '
#   '0.002*"stronghold" + 0.002*"republican stronghold" + 0.002*"fire" + '
#   '0.002*"ran republican stronghold" + 0.002*"ran republican" + '
#   '0.002*"democrat ran"'),
#  (11,
#   '0.003*"trump" + 0.002*"california" + 0.002*"people" + 0.002*"wildfire" + '
#   '0.001*"wildfires" + 0.001*"blames" + 0.001*"fires" + 0.001*"plan" + '
#   '0.001*"real" + 0.001*"ca"'),
#  (12,
#   '0.004*"california" + 0.002*"fires" + 0.002*"trump" + 0.001*"forest" + '
#   '0.001*"wildfires" + 0.001*"president" + 0.001*"new" + 0.001*"management" + '
#   '0.001*"say" + 0.001*"sea"'),
#  (13,
#   '0.003*"fires" + 0.003*"california" + 0.003*"energy" + 0.002*"fossil" + '
#   '0.002*"blame" + 0.002*"fossil fuels" + 0.002*"fuels" + 0.002*"happening" + '
#   '0.002*"fires happening" + 0.002*"california fires"'),
#  (14,
#   '0.003*"people" + 0.002*"california" + 0.001*"one" + 0.001*"says" + '
#   '0.001*"us" + 0.001*"ordinary" + 0.001*"ordinary people" + 0.001*"every" + '
#   '0.001*"according" + 0.001*"researchers"')]

# %% [markdown]
# # Get top words and put them in a from which can be used for google search query

# %%
import re

topic_words = []

for i in lda.print_topics():
    new_row = []
    for j in re.split('\+',i[1]):
        k = re.sub(r"[^A-Za-z ]+", '', str(j))
        k = k.strip()
        k = re.sub(r" ",'+', str(k))
        new_row.append(k)
        
    topic_words.append(new_row)

# %%
import numpy.ma as ma

compressed_topics = []

for topic in np.array(topic_words):

    remove_list = []
    for word1 in topic:
        check = 0
        for word2 in topic:
            if word1 == word2:
                pass
            elif word1 in word2:
                check = 1
        remove_list.append(check)
    mx = ma.masked_array(topic, mask=remove_list)
    compressed_topics.append(list(mx.compressed()))

# %%
for i in compressed_topics:
    print(i)
# Out:
# ['would', 'deserts+help+stop', 'flooding+deserts+help']
# ['california', 'trump', 'fires', 'need', 'get', 'today', 'us', 'sea', 'level']
# ['new', 'even', 'part', 'study', 'big+oil+claims']
# ['california+wildfires', 'us', 'even', 'scientists', 'brown', 'politics', 'trump', 'new']
# ['protesters+blockade', 'blockade+government', 'government+energy+department']
# ['trump', 'neil+young+loses', 'young+loses+home']
# ['jerry+brown+blames', 'california+wildfires', 'blames+california']
# ['neil+young', 'trump', 'home', 'losing', 'california+fires', 'criticises']
# ['real', 'new', 'bears', 'could', 'california', 'polar', 'temperature', 'carbon', 'many', 'energy']
# ['california', 'trump', 'blames', 'fires', 'protests+leads+arrests']
# ['california', 'fire', 'ran+republican+stronghold', 'democrat+ran']
# ['trump', 'california', 'people', 'wildfires', 'blames', 'plan', 'real']
# ['california', 'trump', 'forest', 'wildfires', 'president', 'new', 'management', 'say', 'sea']
# ['energy', 'blame', 'fossil+fuels', 'fires+happening', 'california+fires']
# ['california', 'one', 'says', 'us', 'ordinary+people', 'every', 'according', 'researchers']

# %% [markdown]
# # Create url links for external resources

# %%
url_list = []

for i in compressed_topics:
    search_terms = "+".join(i)
    url = "http://www.google.com/search?q={}&btnI".format(search_terms)
    print(url)
    url_list.append(url)
# Out:
# http://www.google.com/search?q=would+deserts+help+stop+flooding+deserts+help&btnI
# http://www.google.com/search?q=california+trump+fires+need+get+today+us+sea+level&btnI
# http://www.google.com/search?q=new+even+part+study+big+oil+claims&btnI
# http://www.google.com/search?q=california+wildfires+us+even+scientists+brown+politics+trump+new&btnI
# http://www.google.com/search?q=protesters+blockade+blockade+government+government+energy+department&btnI
# http://www.google.com/search?q=trump+neil+young+loses+young+loses+home&btnI
# http://www.google.com/search?q=jerry+brown+blames+california+wildfires+blames+california&btnI
# http://www.google.com/search?q=neil+young+trump+home+losing+california+fires+criticises&btnI
# http://www.google.com/search?q=real+new+bears+could+california+polar+temperature+carbon+many+energy&btnI
# http://www.google.com/search?q=california+trump+blames+fires+protests+leads+arrests&btnI
# http://www.google.com/search?q=california+fire+ran+republican+stronghold+democrat+ran&btnI
# http://www.google.com/search?q=trump+california+people+wildfires+blames+plan+real&btnI
# http://www.google.com/search?q=california+trump+forest+wildfires+president+new+management+say+sea&btnI
# http://www.google.com/search?q=energy+blame+fossil+fuels+fires+happening+california+fires&btnI
# http://www.google.com/search?q=california+one+says+us+ordinary+people+every+according+researchers&btnI

# %% [markdown]
# # Jensen Shannon inequality

# %%
mdiff, annotation = lda.diff(lda, distance='jensen_shannon')

# %%
mdiff
# Out:
# array([[0.        , 0.80907799, 0.84923316, 0.83738829, 0.85821396,
#         0.89331375, 0.89413322, 0.97178084, 0.82462331, 0.87619591,
#         0.85786606, 0.83074138, 0.83262448, 0.85446972, 0.82479364],
#        [0.80907799, 0.        , 0.83121388, 0.81822375, 0.85962288,
#         0.85333438, 0.87962479, 0.90945448, 0.82438849, 0.85994976,
#         0.84522181, 0.81242591, 0.80528339, 0.84015634, 0.80808558],
#        [0.84923316, 0.83121388, 0.        , 0.86041654, 0.8929408 ,
#         0.91393311, 0.93159406, 0.98356384, 0.85325712, 0.90575303,
#         0.86560602, 0.86309918, 0.858615  , 0.87858732, 0.84536188],
#        [0.83738829, 0.81822375, 0.86041654, 0.        , 0.8818932 ,
#         0.88398522, 0.86356175, 0.95574487, 0.8475964 , 0.88649668,
#         0.86349836, 0.84178394, 0.83369558, 0.85996186, 0.83048798],
#        [0.85821396, 0.85962288, 0.8929408 , 0.8818932 , 0.        ,
#         0.92515659, 0.93475861, 1.        , 0.86517598, 0.90285062,
#         0.89451231, 0.88268644, 0.88385927, 0.88304039, 0.86902977],
#        [0.89331375, 0.85333438, 0.91393311, 0.88398522, 0.92515659,
#         0.        , 0.91359387, 0.90520873, 0.89530572, 0.92914078,
#         0.89152625, 0.87613841, 0.87335446, 0.91364053, 0.87204223],
#        [0.89413322, 0.87962479, 0.93159406, 0.86356175, 0.93475861,
#         0.91359387, 0.        , 0.96320931, 0.90666792, 0.91567361,
#         0.91350366, 0.87164851, 0.87836074, 0.91577181, 0.90101015],
#        [0.97178084, 0.90945448, 0.98356384, 0.95574487, 1.        ,
#         0.90520873, 0.96320931, 0.        , 0.97212218, 0.97493497,
#         0.9670969 , 0.94729231, 0.93897107, 0.97130532, 0.95629926],
#        [0.82462331, 0.82438849, 0.85325712, 0.8475964 , 0.86517598,
#         0.89530572, 0.90666792, 0.97212218, 0.        , 0.89593367,
#         0.86690219, 0.8373085 , 0.84856376, 0.86067044, 0.83791383],
#        [0.87619591, 0.85994976, 0.90575303, 0.88649668, 0.90285062,
#         0.92914078, 0.91567361, 0.97493497, 0.89593367, 0.        ,
#         0.9096391 , 0.87422875, 0.87545001, 0.89081952, 0.87906015],
#        [0.85786606, 0.84522181, 0.86560602, 0.86349836, 0.89451231,
#         0.89152625, 0.91350366, 0.9670969 , 0.86690219, 0.9096391 ,
#         0.        , 0.85894473, 0.85729503, 0.8832663 , 0.84979528],
#        [0.83074138, 0.81242591, 0.86309918, 0.84178394, 0.88268644,
#         0.87613841, 0.87164851, 0.94729231, 0.8373085 , 0.87422875,
#         0.85894473, 0.        , 0.83423416, 0.8597347 , 0.83490406],
#        [0.83262448, 0.80528339, 0.858615  , 0.83369558, 0.88385927,
#         0.87335446, 0.87836074, 0.93897107, 0.84856376, 0.87545001,
#         0.85729503, 0.83423416, 0.        , 0.85514055, 0.83252577],
#        [0.85446972, 0.84015634, 0.87858732, 0.85996186, 0.88304039,
#         0.91364053, 0.91577181, 0.97130532, 0.86067044, 0.89081952,
#         0.8832663 , 0.8597347 , 0.85514055, 0.        , 0.84892965],
#        [0.82479364, 0.80808558, 0.84536188, 0.83048798, 0.86902977,
#         0.87204223, 0.90101015, 0.95629926, 0.83791383, 0.87906015,
#         0.84979528, 0.83490406, 0.83252577, 0.84892965, 0.        ]])

# %%
differences = []

for i,v in enumerate(mdiff):
    print(i)
    print(sum(v))
    differences.append(sum(v))
# Out:
# 0
# 12.01445571225112
# 1
# 11.75606342891445
# 2
# 12.333174909578235
# 3
# 12.064734418114286
# 4
# 12.533740812795415
# 5
# 12.539674010825392
# 6
# 12.683112022101415
# 7
# 13.41698407467131
# 8
# 12.136429504651822
# 9
# 12.576126551798936
# 10
# 12.324674002417973
# 11
# 12.025170964818324
# 12
# 12.007973257689002
# 13
# 12.315494448582761
# 14
# 11.990239241449236

# %% [markdown]
# # Get tweets in each topic, for sentiment analysis per topic

# %%
corpus_topics = []

for i in range(0,len(corpus)):
    top_topics = lda.get_document_topics(corpus[i])
    top_topics.sort(key=lambda x: x[1], reverse=True)
    corpus_topics.append(top_topics[0][0])

# %%
clustered_corpus = list(zip(train_text,corpus_topics))

# %%
clustered_tweets = []

for i in range(0,20):
    temp_list = []
    for j in clustered_corpus:
        if i == j[1]:
            temp_list.append(j[0])
            
    clustered_tweets.append(temp_list)

# %% [markdown]
# # Sentiment Analysis

# %%
from textblob import TextBlob

# %%
average_polarity = []
average_subjectivity = []


for i in range(0,20):
    polarity = [] # Lies in range [-1,1]  Very negative sentiment to very positive
    subjectivity = [] # [0,1] Very objective statement to very subjective statement
    for current_tweet in tqdm(clustered_tweets[i]):
        text = TextBlob(current_tweet).sentiment

        polarity.append(text.polarity)
        subjectivity.append(text.subjectivity)
        
    average_polarity.append(np.mean(polarity))
    average_subjectivity.append(np.mean(subjectivity))
# Out:
# 100%|██████████| 695/695 [00:00<00:00, 2055.33it/s]
# 100%|██████████| 501/501 [00:00<00:00, 2017.71it/s]
# 100%|██████████| 591/591 [00:00<00:00, 1905.76it/s]
# 100%|██████████| 625/625 [00:00<00:00, 2056.48it/s]
# 100%|██████████| 690/690 [00:00<00:00, 1937.06it/s]
# 100%|██████████| 677/677 [00:00<00:00, 1860.07it/s]
# 100%|██████████| 820/820 [00:00<00:00, 1846.85it/s]
# 100%|██████████| 869/869 [00:00<00:00, 1888.34it/s]
# 100%|██████████| 625/625 [00:00<00:00, 1856.85it/s]
# 100%|██████████| 782/782 [00:00<00:00, 1910.42it/s]
# 100%|██████████| 661/661 [00:00<00:00, 1798.47it/s]
# 100%|██████████| 622/622 [00:00<00:00, 1828.79it/s]
# 100%|██████████| 632/632 [00:00<00:00, 1750.49it/s]
# 100%|██████████| 636/636 [00:00<00:00, 1839.08it/s]
# 100%|██████████| 574/574 [00:00<00:00, 1816.32it/s]
# 0it [00:00, ?it/s]
# /Users/nazim/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/nazim/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
average_polarity
# Out:
# [0.04585297584443269,
#  0.05585492315033233,
#  0.11821968103735539,
#  0.05050814602064602,
#  0.03751016113516114,
#  0.019643401793512576,
#  0.04748294373027605,
#  0.05443266989584596,
#  0.04151953084415584,
#  0.0356266936122275,
#  0.04565104876422955,
#  0.029615898979845928,
#  0.032975253305356146,
#  0.043571182482640816,
#  0.024402216208346438,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %% [markdown]
# # Using Vader

# %%
clustered_tweets[0]
# Out:
# ['https://t.co/J8n4Qr3z7A',
#  'God the absolute tragic irony of an actor who’d starred in a film about enormous catastrophic climate change being… https://t.co/oGBGQW0Kih',
#  'https://t.co/W0h7SiOQiO',
#  'https://t.co/hCn1xt1z8f',
#  'https://t.co/pTm4IFii5O',
#  "Sooooo, the climate started the fires? Sounds like he's deflecting from CA not practicing land management in order… https://t.co/szetGXBF14",
#  'Let the democrats keep this N mind &amp; root out every bit of this network of corruption. Root it ALL out, every Russi… https://t.co/P1Yktz9TJI',
#  "Jean Paul Gaultier Drops Fur, Calls Industry 'Absolutely Deplorable' https://t.co/AT9Z0aoPrI #climate #organic… https://t.co/hunY0WkvOn",
#  '“Our ultimate goal is for a low carbon sustainable future for all Africans and the shift from fossil fuels like coa… https://t.co/M3LTHG5GZG',
#  '” If she’s right, maybe the sea change in public action we desperately need is closer than it seems. It would certa… https://t.co/PHHC4LvZKq',
#  '"Sadly, far too much media coverage has failed to draw that link. It fits (the) trend of big news orgs investing in… https://t.co/SgrnYOJLtM',
#  '.@KQED please share with your reporter who told @NPR this morning the main reason for the ferocity of the fires is… https://t.co/16krKjxrQb',
#  'Shifting public attitudes to combat climate change #ConSocSci #BehaviorChange #Conpsych https://t.co/Ch9JDFphnp',
#  'MUST WATCH AND SHARE VERY WIDELY - MODEL TO COPY &amp; IMPLEMENT EVERYWHERE - SOLAR IS A MAJOR WAYTO REVERSE CLIMATE CH… https://t.co/adh1brUkL1',
#  'According to Neil Young’s logic, these #CaliforniaFires just wouldn’t be happening if Hillary was elected. So, he m… https://t.co/Q9rEflF93j',
#  'https://t.co/lDAbcEZ60U',
#  'https://t.co/YjLQ1MxGod',
#  '#AfricanIslands are looking for help as climate change creates a health crisis https://t.co/MNcblm8RzA',
#  'No end in sight for CA fires, the most destructive so far in CA history. As we pray, may we learn. Climate change i… https://t.co/TpMg1as7qX',
#  "James is speaking @TEDXBONN on Sat 17 Nov. The evening's topics are climate change, cities and art (he's talking ab… https://t.co/u9dv9wiTgQ",
#  'https://t.co/UmQQNk8HGy',
#  'Spain’s new and ambitious minister for the ecological transition «aims to carry out the energy transition in a way… https://t.co/nvSzOCtPuM',
#  'Snow just started... This is Arkansas &amp; Nov not usual for snow. I thought snow was going to be a rare event by now.… https://t.co/xVPyPNnSE5',
#  'https://t.co/2k4TZMytq5',
#  "Climate Change Isn't Causing California Wildfires - Blame Lies with Bad Forest Management, says @merrillmatthews https://t.co/Jz8FWntt60",
#  'As has been routinely proven in various studies, including an impact assessment by @EU_Commission,… https://t.co/XgNELt4yzP',
#  'Climate change effect on public health is my dad developing asthma from growing up with smokers and me possibly dev… https://t.co/yh8RRNmpGn',
#  "Farmers in tropical and subtropical regions are already feeling the impacts of #climatechange. That's why we must d… https://t.co/kAPGOcBIfe",
#  'The #RiskAquaSoil partners from NUI Galway were at the National Rural Network and the Department of Agriculture in… https://t.co/K0Z9JPmvEK',
#  'Open PhD assistantship with me at Virginia Tech studying communication, collaborative learning, and collective acti… https://t.co/WK12EOegKS',
#  'https://t.co/7BLGw3aupW',
#  "Maldives: climate change could actually help coral islands rise again – but they're still at risk… https://t.co/wJgkF86FFV",
#  'If you think global warming isnt an objective truth at this point your delusions are such that organized religion c… https://t.co/1Q6cW0BgeC',
#  '"The world’s biggest #energy #companies are spending only a fraction of their investment budgets on #lowcarbon proj… https://t.co/J1EICPZsY8',
#  'Maybe the global warming alarmists will go harass China now and leave us alone......... https://t.co/fHPTMxpW5N',
#  'The most authoritative body on #climatechange has confirmed we are drastically off track from the action we need on… https://t.co/hCHwifiLTT',
#  'Yes, Climate Change!\n\nAnd the trees are fire resistant. https://t.co/aswT5z8oCC',
#  "Arrested and charged seems like the next step...Jerry Brown: Climate Change Deniers 'Definitely Contributing' to th… https://t.co/mMGJwer7xl",
#  'Thanks @howarth_cornell for your words to the PDEQ Committee of the Tompkins County Legislature! "In his public tes… https://t.co/qtTvdcvWfe',
#  'one of my students just cauterized my mouth shut before i could argue about climate change and honestly fair point',
#  'Why banning fossil fuels is more urgent than ever. New blog by #PitPoint CEO, @ErikKemink: https://t.co/OiMcZu3nol… https://t.co/cQTwUPjiaq',
#  'Would flooding the deserts help stop global warming? https://t.co/bzkuQrs6k2',
#  'Would flooding the deserts help stop global warming? https://t.co/Uajh36GZeE',
#  'There is one major political party on earth that is full of climate change deniers and that is the GOP, but leave i… https://t.co/iNU72G5Jul',
#  '#ICFP2018 "We have a record breaking # of family planning champions gathered here. We care about gender equity, wom… https://t.co/aMIarOSsKC',
#  'this https://t.co/PM088dQKT6',
#  'Could Flooding Deserts Help Stop Global Warming? https://t.co/35ypw85rB5',
#  'Associate Environmental &amp; Social Investment Advisory Specialist https://t.co/hBVt6a0pLe #jobs #climatechange',
#  'https://t.co/c4b9p2P32u',
#  'గ్లోబల్\u200c ‘వార్నింగ్’ నుంచి ఓజోన్\u200c భరోసా\n#GlobalWarming #V6News https://t.co/NwuO2Ua4kU',
#  'To help finance natural infrastructure projects, communities need to look for unique, cost-effective solutions that… https://t.co/NZPd6ODjhk',
#  'Why Catastrophic Climate Change is Probably Inevitable Now\nHow Capitalism Torched the Planet by Imploding Into Fasc… https://t.co/nlZFgVj3l5',
#  'Our new article evaluates the quality of #ClimateChange plans in 63 Canadian cities. Wide variation, but:\n- GHG red… https://t.co/JWNapeGV15',
#  'Global warming. https://t.co/1YsIUbHkq1',
#  'Maldives: how climate change could actually help coral islands rise again https://t.co/gw1ApkM58D',
#  'First @axlrose, now Neil Young schooling the President on forest fires and climate change. Anymore iconic American… https://t.co/pcdgy5aPXT',
#  'Pentagon Signals Security Risks of #ClimateChange https://t.co/gVI4NPP1c2 https://t.co/oiqewcmser',
#  "Doing 1 Thing To Change Our Climate Polluting Ways.  \n\n...Today's blog addresses our motivations.… https://t.co/J4MWcetco0",
#  '#GlobalWarming',
#  'CA why don’t you use: A controlled or prescribed burn, also known as hazard reduction burning,[1backfire, swailing,… https://t.co/fe77bGnfBD',
#  'To fight #ClimateChange, environmentalists say yes to #NuclearPower \n\n#TheFutureIsNuclear\nhttps://t.co/9vYwv07HFU',
#  'It is beginning to look like it will be up to us on social media who want something done about climate change. https://t.co/LA7xrf5vwm',
#  'What effect does #ClimateChange have on droughts in Australia? The @guardian delve into the latest climate data,\xa0an… https://t.co/cnkyznupDh',
#  'Today is the first day of Thanksgiving #fast and #prayer (liquid diet until sunset Nov 12 - 21) to address… https://t.co/t10DAj0ZcD',
#  'https://t.co/5lYNIOwjga',
#  'Could nuclear power play a major role in reversing climate change? https://t.co/qz2CzyEC7M',
#  'A Very Grim Forecast https://t.co/pHAvImUcD8 via @nybooks',
#  'Global Warming Hoax- Updates - The Plain Truth - News and Message Board https://t.co/EREViKjy1k',
#  'We must create groups for all the population of the world in order to they cooperate &amp; to find the solutions for di… https://t.co/4QADShJU4R',
#  'So the oxybrillo tech in @dadwroteaporno could surely be used to power steam generators, thus generating completely… https://t.co/qDgqROneSN',
#  '#COP24: about to discuss #climate issues in Stockholm! Yes, important! https://t.co/44fwl3b1s4',
#  'Climate Change: https://t.co/cfGlQ09DEq',
#  '\u2066@LeoDiCaprio\u2069 🗣it’s the climate change 🤔global warming \U0001f92a\u2066@katyperry\u2069 🗣its \u2066@POTUS\u2069 and political rhetoric These ve… https://t.co/cfYkpVnpAU',
#  'Could Flooding Deserts Help Stop Global Warming?: Flooding a massive desert with desalinated ocean water to grow en… https://t.co/qBOJIPc5hD',
#  'vaping is causing global warming, can you guys pls stop vaping',
#  "The #IPCC warns of catastrophic impacts if #fossilfuel use isn't halved by 2030. Today we're calling on Ottawa to e… https://t.co/LI8HfteMkn",
#  'the weather is saying we might get snow and im like\nsnow in tn??? this early??\nthis is what global warming does, we… https://t.co/0rRMrBRkhN',
#  'https://t.co/tMmTULVy4T',
#  "Impressed by the quality of @hasanminhaj's commentary on the #energy sector and #climatechange in #PatriotAct. High… https://t.co/Rp8Kv1tZgo",
#  "Fascinating: Canadian Inuits say Polar Bear numbers are out of control, with so many around they've become a big th… https://t.co/KGUEssyV3r",
#  'Think fertilizer &amp; good soil health only contribute to #SDG2 on #zerohunger? They play a role in goals on poverty,… https://t.co/TZ4z64blXR',
#  "Here's the EPA HFC phaseout status after the SNAP Rule 20 lawsuit: https://t.co/Ac4cBC56qe. #HVACR #HVAC… https://t.co/Ij9SSZtwYX",
#  "New strategy sets tone to make Edmonton 'climate resilient' | CBC News https://t.co/1JfdmqMpCZ",
#  '“With the disruption of rainfall, #dengue is now persistent and continuous...” https://t.co/cjwZq5d0rf #Africa #climatechange',
#  'If the GOP want to attract Millenials and keep Republican Millenials, then they need to re-think their stance on en… https://t.co/tA4PkmODM2',
#  'He’s not heartless. He’s right. The idiots would rather cry on camera than look at reality. And no, it’s not… https://t.co/4ZeJyrz4pE',
#  'Opening ceremony at @UWI_StAugustine faculty of food and agriculture conference on #ClimateChange impacts on… https://t.co/EK7NiwDvH2',
#  '#climatechange https://t.co/W8KDxKbVhn',
#  'Midterms 2018: climate politics are polarized, but Democrats can still move forward - Vox https://t.co/B3NoX2moyO',
#  'I clicked to stop global warming @Care2: https://t.co/wc9W75HzXY',
#  'LA News Could Flooding Deserts Help Stop Global Warming? https://t.co/ZYIkqNobc3 https://t.co/B680t27wnL',
#  'PG&amp;E trying to speak and give updates on fire they may have started\n\nLame duck Brown sticking up for PG&amp;E blaming t… https://t.co/DOJotc0Lgh',
#  'WHO DID GLOBAL WARMING',
#  'Would flooding the deserts help stop global warming? - https://t.co/yuFi5LJZaC https://t.co/y3VLHgZzSS',
#  'Could Flooding Deserts Help Stop Global Warming?: Flooding a massive desert with desalinated ocean water to grow en… https://t.co/riKY0iq2Iv',
#  'At @Africities8, we will talk abt #city2city #cooperation, #GenderEquality, #Youth, #ClimateChange &amp; Financing with… https://t.co/hFQVOQSlBT',
#  'Democrats need to put climate policy on the table again. Grass roots support will give it traction. Gains are possi… https://t.co/5Vpi4ZhMrd',
#  'Would flooding the deserts help stop global warming? - https://t.co/DmiWOJx7As https://t.co/Dim0NXplsD',
#  'One radar alone maybe is not worthy, but a network sounds better.\nhttps://t.co/AnUBw1FkBk\n#Piura #Peru #climate #science #technology',
#  'Once lush, El Salvador is dangerously close to running dry; numerous causes of growing water crisis, including clim… https://t.co/J36wl9fltC',
#  'We are pleased to announce our partnership with @CCACoalition to work together in the lead up to, and during #COP24… https://t.co/q5WYyo1v0b',
#  '” If she’s right, maybe the sea change in public action we desperately need is closer than it seems. It would certa… https://t.co/PHHC4LvZKq',
#  '"Sadly, far too much media coverage has failed to draw that link. It fits (the) trend of big news orgs investing in… https://t.co/SgrnYOJLtM',
#  "I’ve seen the #Antarctic’s #untouched #beauty. There's still #time to #protect it | Javier Bardem https://t.co/eTLCLueN4s",
#  "Jerry Brown Blames Global Warming On Climate Change.\nHe's a Liar! He Started The Fires 2 Cover Stolen Funds, with Fed Emergency Relief Funds",
#  'https://t.co/wubD8nEwgv',
#  'To #ActOnClimate, we need climate change champions at all levels of government! With more Democrats elected as gove… https://t.co/l8NoDxoQVa',
#  'New #blog \nhttps://t.co/OkPpHqxZfA \n#blogging #climatejustice #climatechange #futuregenerations #behaviour… https://t.co/Z6TXm9mmmN',
#  'https://t.co/P9Ib28X9CB',
#  'Are we awake yet to the reality of climate change and the outcomes of a hotter, dryer environment.… https://t.co/lBt2grToGn',
#  'What are some of the many risks of thawing permafrost?\nhttps://t.co/eIivtE0BwL\n#climatechange #climateaction https://t.co/DyXv1L29d8',
#  'global warming, deforestation and recycling are seriously important topics that nobody ! gives ! a ! shit ! about !',
#  'scientist take a specialised engineered liquid expose it to the sun and it stores the energy which can be stored fo… https://t.co/rOvAJYvsqU',
#  'Absolutely @PeterDiamandis this is insane and so is the belief from some including Trump that there’s no climate ch… https://t.co/ojSlmYmKx4',
#  'https://t.co/qVD4ecCx2Z',
#  'https://t.co/W0mez00rEY',
#  'Could flooding deserts help stop global warming? https://t.co/iLNhL8gqff',
#  'https://t.co/1OGm2LdgeL',
#  'Chicago Democrat Rep Ran on Climate Change in a Republican Stronghold—and Won  https://t.co/BhBRW5eJfw',
#  'https://t.co/NWB5PqCFsc https://t.co/9I35kCXLG9',
#  "Was honoured to chair today's discussions on scaling up climate smart agriculture (CSA) and impacts of climate info… https://t.co/yNIb9WdPCw",
#  'https://t.co/g1n5JwReEd',
#  'https://t.co/O67BBCW8zK',
#  'Reasons to be cheerful: the capacity of #renewable_energy has overtaken that of #FossilFuels in the UK for the firs… https://t.co/GT8FPCfQJp',
#  '😳 https://t.co/U1LmaZL7oZ',
#  '#weneedguncontrol now. #neveragain We can’t allow nihilism, selfishness, resign &amp; violence to be our answer to… https://t.co/bs5ISYyxEl',
#  "Talked about this on Saturday, shout out to @theNRMLC I wish I had this article, then! “I'm a woman who fought wild… https://t.co/ei0hqc6XTr"]

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyser = SentimentIntensityAnalyzer()

# %%
average_polarity = []

for i in range(0,20):
    polarity = [] # Lies in range [-1,1]  Very negative sentiment to very positive

    for current_tweet in tqdm(clustered_tweets[i]):
        pol = analyser.polarity_scores(current_tweet)
        polarity.append(pol)
        if pol['compound']<-0.85:
            print(pol['compound'])
            print(current_tweet)

    
    comp = []
    
    for j in polarity:
        comp.append(j['compound'])
        
    average_polarity.append(round(((np.mean(comp)+1)/2)*100,2))
# Out:
# 100%|██████████| 695/695 [00:00<00:00, 3226.00it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
# -0.8652
# What THE FUCK is up with this weather? I'm from Arizona, i'm freezing my nuts off in this shit. Days like this make… https://t.co/GnfHckLNza
# -0.9001
# New article about #climate from Guardian: You thought fake news was bad? Deep fakes are where truth goes to die https://t.co/C6zNEAlwVu
# -0.9001
# At least 29 dead in #CampFire, 2 dead in #WoolsyFire. Camp fire is 25% contained, Woolsey is 20%. Santa Anas expect… https://t.co/LfexgDsLKC
# -0.9306
# Pisses me off that people are blaming Trump for the fires... HOW THE FUCK IS IT HIS FAULT!?! NEWSFLASH: YOUR PRECIO… https://t.co/1cakcr5GtN
# -0.8983
# Climate Change is real and for dooming us all, F*~&gt; people who deny or don't care! 🤬
#
# Plant trees, reduce waste, pr… https://t.co/ZvTwHRZFpO
# 100%|██████████| 574/574 [00:00<00:00, 2865.80it/s]
# 0it [00:00, ?it/s]
# /Users/nazim/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/nazim/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# -0.8553
# She thinks your husband is a fucking dipshit for thinking climate change is fake and she also hates him for opening… https://t.co/MMFYuSFXHN
# -0.9178
# Crazy thought, but what with debt levels reaching crisis points across the globe, massive borrowing, insane consump… https://t.co/NWoYDefBhv
# -0.8625
# #climatechange @UN_HRC government in Chile attacks with repression with physical and psychological violence against… https://t.co/gpSQIlvcXa
# -0.8689
# OMG and the "Rosa Parks is too politically correct" but NO ONE gave a shit when there were hundreds of Ecclestone/T… https://t.co/kAHaDYPpdg
# -0.9168
# TAKE A FEW MORE YARDS, THEY GOT A LOT OF FOLKS TO IGNORE FACTS ABOUT FAKE CLIMATE CHANGE, FRAUD! VOTE FOR ACTS BEFO… https://t.co/q2KLzkjmXA
# -0.8748
# Jerry Brown Blames Climate Change for California Wildfires. Talk about ignoring science! All those dead trees you r… https://t.co/xLJJXkN2YZ
# -0.8903
# You fucking, moronic, racist pig. No help for California because the mismanaged their land use. Hey jackass. It’s b… https://t.co/l9zAn3vXUa

# %%
no_tweets = []

for i in clustered_tweets:
    print(len(i))
    no_tweets.append(len(i))
# Out:
# 695
# 501
# 591
# 625
# 690
# 677
# 820
# 869
# 625
# 782
# 661
# 622
# 632
# 636
# 574
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# # Scrape images using BeauituflSoup and crate a dictionary to store information for Flask app

# %%
from collections import defaultdict
from bs4 import BeautifulSoup
import urllib
import ssl
import os

climate_topics = []

ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

num = 1


for i,v in enumerate(compressed_topics):
    topic_dict = {}
    topic_dict['topic'] = [' '.join(k.split('+')) for k in v[0:5]]
    topic_dict['topic_no'] = num
    topic_dict['link'] = url_list[i]
    topic_dict['image'] = "/static/c"+str(num)+".jpg"
    topic_dict['no_tweets'] = no_tweets[num-1]
    topic_dict['sent'] = average_polarity[num-1]
    
    if average_polarity[num-1] > 50:
        topic_dict['sent_color'] = 'mediumseagreen'
    else:
        topic_dict['sent_color'] = 'orangered'
    
    climate_topics.append(topic_dict)
    
    if len(v)>5:
        print('hello')
        v = v[:6]
    
    #v.sort(key = len,reverse=True)
 
    
    query = "+".join(v[0:5])
    print(query)
    
    url = "http://www.bing.com/image/search?q=%s" % (query)
    uh= urllib.request.urlopen(url, context=ctx)
    html =uh.read().decode()
    
    try:
        soup = BeautifulSoup(html, 'html.parser')
        mydiv = soup.find("div", class_="img_cont hoff")
        link = mydiv.findChildren()[0]['src']
        
    except AttributeError:     
        
        query = "+".join(v[0:1])
        print(query)
        url = "http://www.bing.com/image/search?q=%s" % (query)
        uh= urllib.request.urlopen(url, context=ctx)
        html =uh.read().decode()
        soup = BeautifulSoup(html, 'html.parser')
        mydiv = soup.find("div", class_="img_cont hoff")
        link = mydiv.findChildren()[0]['src']
        

    
    fullfilename = os.path.join('/Users/nazim/Desktop/project_fletcher/flask_app/static', "c"+str(num)+".jpg")
    urllib.request.urlretrieve(str(link), fullfilename)
    num +=1
# Out:
# flooding+deserts+help+deserts+help+stop+would
# hello
# california+trump+fires+today+level
# big+oil+claims+study+even+part+new
# hello
# california+wildfires+scientists+politics+brown+trump
# government+energy+department+protesters+blockade+blockade+government
# neil+young+loses+young+loses+home+trump
# california+wildfires+jerry+brown+blames+blames+california
# hello
# california+fires+neil+young+criticises+losing+trump
# california+fires
# hello
# temperature+california+carbon+energy+bears
# protests+leads+arrests+california+blames+trump+fires
# ran+republican+stronghold+democrat+ran+california+fire
# hello
# california+wildfires+people+blames+trump
# hello
# california+management+wildfires+president+forest
# california+fires+fires+happening+fossil+fuels+energy+blame
# california+fires
# hello
# ordinary+people+researchers+california+according+every

# %%
climate_topics
# Out:
# [{'topic': ['flooding deserts help', 'deserts help stop', 'would'],
#   'topic_no': 1,
#   'link': 'http://www.google.com/search?q=would+deserts+help+stop+flooding+deserts+help&btnI',
#   'image': '/static/c1.jpg',
#   'no_tweets': 695,
#   'sent': 52.28,
#   'sent_color': 'mediumseagreen'},
#  {'topic': ['california', 'trump', 'fires', 'today', 'level'],
#   'topic_no': 2,
#   'link': 'http://www.google.com/search?q=california+trump+fires+need+get+today+us+sea+level&btnI',
#   'image': '/static/c2.jpg',
#   'no_tweets': 501,
#   'sent': 49.32,
#   'sent_color': 'orangered'},
#  {'topic': ['big oil claims', 'study', 'even', 'part', 'new'],
#   'topic_no': 3,
#   'link': 'http://www.google.com/search?q=new+even+part+study+big+oil+claims&btnI',
#   'image': '/static/c3.jpg',
#   'no_tweets': 591,
#   'sent': 53.03,
#   'sent_color': 'mediumseagreen'},
#  {'topic': ['california wildfires',
#    'scientists',
#    'politics',
#    'brown',
#    'trump'],
#   'topic_no': 4,
#   'link': 'http://www.google.com/search?q=california+wildfires+us+even+scientists+brown+politics+trump+new&btnI',
#   'image': '/static/c4.jpg',
#   'no_tweets': 625,
#   'sent': 49.5,
#   'sent_color': 'orangered'},
#  {'topic': ['government energy department',
#    'protesters blockade',
#    'blockade government'],
#   'topic_no': 5,
#   'link': 'http://www.google.com/search?q=protesters+blockade+blockade+government+government+energy+department&btnI',
#   'image': '/static/c5.jpg',
#   'no_tweets': 690,
#   'sent': 47.6,
#   'sent_color': 'orangered'},
#  {'topic': ['neil young loses', 'young loses home', 'trump'],
#   'topic_no': 6,
#   'link': 'http://www.google.com/search?q=trump+neil+young+loses+young+loses+home&btnI',
#   'image': '/static/c6.jpg',
#   'no_tweets': 677,
#   'sent': 44.04,
#   'sent_color': 'orangered'},
#  {'topic': ['california wildfires', 'jerry brown blames', 'blames california'],
#   'topic_no': 7,
#   'link': 'http://www.google.com/search?q=jerry+brown+blames+california+wildfires+blames+california&btnI',
#   'image': '/static/c7.jpg',
#   'no_tweets': 820,
#   'sent': 44.22,
#   'sent_color': 'orangered'},
#  {'topic': ['california fires', 'neil young', 'criticises', 'losing', 'trump'],
#   'topic_no': 8,
#   'link': 'http://www.google.com/search?q=neil+young+trump+home+losing+california+fires+criticises&btnI',
#   'image': '/static/c8.jpg',
#   'no_tweets': 869,
#   'sent': 38.9,
#   'sent_color': 'orangered'},
#  {'topic': ['temperature', 'california', 'carbon', 'energy', 'bears'],
#   'topic_no': 9,
#   'link': 'http://www.google.com/search?q=real+new+bears+could+california+polar+temperature+carbon+many+energy&btnI',
#   'image': '/static/c9.jpg',
#   'no_tweets': 625,
#   'sent': 49.84,
#   'sent_color': 'orangered'},
#  {'topic': ['protests leads arrests',
#    'california',
#    'blames',
#    'trump',
#    'fires'],
#   'topic_no': 10,
#   'link': 'http://www.google.com/search?q=california+trump+blames+fires+protests+leads+arrests&btnI',
#   'image': '/static/c10.jpg',
#   'no_tweets': 782,
#   'sent': 43.92,
#   'sent_color': 'orangered'},
#  {'topic': ['ran republican stronghold', 'democrat ran', 'california', 'fire'],
#   'topic_no': 11,
#   'link': 'http://www.google.com/search?q=california+fire+ran+republican+stronghold+democrat+ran&btnI',
#   'image': '/static/c11.jpg',
#   'no_tweets': 661,
#   'sent': 49.76,
#   'sent_color': 'orangered'},
#  {'topic': ['california', 'wildfires', 'people', 'blames', 'trump'],
#   'topic_no': 12,
#   'link': 'http://www.google.com/search?q=trump+california+people+wildfires+blames+plan+real&btnI',
#   'image': '/static/c12.jpg',
#   'no_tweets': 622,
#   'sent': 49.15,
#   'sent_color': 'orangered'},
#  {'topic': ['california', 'management', 'wildfires', 'president', 'forest'],
#   'topic_no': 13,
#   'link': 'http://www.google.com/search?q=california+trump+forest+wildfires+president+new+management+say+sea&btnI',
#   'image': '/static/c13.jpg',
#   'no_tweets': 632,
#   'sent': 48.83,
#   'sent_color': 'orangered'},
#  {'topic': ['california fires',
#    'fires happening',
#    'fossil fuels',
#    'energy',
#    'blame'],
#   'topic_no': 14,
#   'link': 'http://www.google.com/search?q=energy+blame+fossil+fuels+fires+happening+california+fires&btnI',
#   'image': '/static/c14.jpg',
#   'no_tweets': 636,
#   'sent': 48.11,
#   'sent_color': 'orangered'},
#  {'topic': ['ordinary people',
#    'researchers',
#    'california',
#    'according',
#    'every'],
#   'topic_no': 15,
#   'link': 'http://www.google.com/search?q=california+one+says+us+ordinary+people+every+according+researchers&btnI',
#   'image': '/static/c15.jpg',
#   'no_tweets': 574,
#   'sent': 52.16,
#   'sent_color': 'mediumseagreen'}]

# %% [markdown]
# # Pickle dictionary with information

# %%
import pickle

with open('climate.pkl', 'wb') as picklefile:
    pickle.dump(climate_topics, picklefile)
    
with open('climate_lda.pkl', 'wb') as picklefile:
    pickle.dump(lda, picklefile)
